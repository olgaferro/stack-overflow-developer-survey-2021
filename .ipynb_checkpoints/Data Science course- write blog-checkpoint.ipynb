# %% [markdown]
# ### Data Science course. Write a Data Science blog
#
# PROJECT
#
# 1. In which US states do you earn the most as a full-time developer?
#
# 2. What is the level education  in the  top countries?
#
# 3. What is the OpSys most used in the  top countries?

# %% [markdown]
# ###  First step clone the repository
#
# ### !git clone https://github.com/olgaferro/stack-overflow-developer-survey-2021.git

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
from currency_converter import CurrencyConverter
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from IPython.display import HTML


import seaborn as sns
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')

schema=pd.read_csv('./survey_results_schema.csv')

c = CurrencyConverter()

df.head()
#df.hist()

# %% [markdown]
# ### 1. Data undersdanting
#
#
# The following analysis is about a 2021 Stackoverflow survey. The survey contains questions about income, employment, education level, age coding, gender, ethnicity, country, etc.
# With this information we are try to answer the next questions.
#
#
# 1. In which US states do you earn the most as a full-time developer?
#
# 2. What is the level education  in the  top countries?
#
# 3. What is the OpSys most used in the  top countries?

# %% [markdown]
# ### 2. Data PREPARING
#
#
# Firstly we are going to prepare the data with the information we need.
#
#
# #Data understanding
# #Data Preparation
# #Modeling
# #Evaluation
# #Deployment

# %%
# 2.1 We are going take a look in the inicial dataframe

num_rows =df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1] #Provide the number of columns in the dataset


print('The inicial dataframe  has rows:%d  and columns: %d'  % (num_rows, num_cols))
# Out:
# The inicial dataframe  has rows:83439  and columns: 48

# %%
# 2.1.1 A look inside the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
# 2.2. Select the important columns for our research

selected_columns = ['ResponseId','MainBranch','Employment','Country','Currency','US_State','EdLevel','Gender','Age','YearsCode','CompTotal','OpSys','DevType']

df_selected_cols = df[selected_columns].copy()

# %%
# 2.3 We are going to focus in Respondents who are - Developers- and - Work full-time-

# Select Developers
df_dev = df_selected_cols[df_selected_cols.MainBranch=='I am a developer by profession']

# Select Employed full time
df_dev_full_time = df_dev[df_selected_cols.Employment=='Employed full-time']

# Select US
df_dev_full_time_us = df_dev_full_time[df_selected_cols.Country=='United States of America']

# Currency dolar
df_dev_full_time_us=df_dev_full_time_us[df_dev_full_time_us['Currency'].str.contains("USD")]


# Fill with the mode  for dataframe US
df_dev_full_time_us['CompTotal'] = df_dev_full_time_us['CompTotal'].fillna(df_dev_full_time_us['CompTotal'].mode()[0])

# Fill with the mode  for dataframe all countries
df_dev_full_time['CompTotal'] = df_dev_full_time['CompTotal'].fillna(df_dev_full_time_us['CompTotal'].mode()[0])

#df_dev_full_time_drops_miss_rows = df_dev_full_time_us.dropna(subset=['CompTotal'])


# We are going to drop columns MainBranch and Employment because now don´t give us any information, because the respondends are all Developers and full time
df_dev_full_time_drops_miss_rows=df_dev_full_time_us.drop(['MainBranch','Employment'], axis=1)



print('The df developers who works full time has rows:%d  and columns: %d'  % (df_dev_full_time_drops_miss_rows.shape[0], df_dev_full_time_drops_miss_rows.shape[1]))
df_dev_full_time_drops_miss_rows.head(100)
# Out:
# The df developers who works full time has rows:9641  and columns: 11
#       ResponseId                   Country                   Currency  \
# 36            37  United States of America  USD\tUnited States dollar
# 37            38  United States of America  USD\tUnited States dollar
# 75            76  United States of America  USD\tUnited States dollar
# 87            88  United States of America  USD\tUnited States dollar
# 118          119  United States of America  USD\tUnited States dollar
# ...          ...                       ...                        ...
# 1068        1069  United States of America  USD\tUnited States dollar
# 1070        1071  United States of America  USD\tUnited States dollar
# 1077        1078  United States of America  USD\tUnited States dollar
# 1080        1081  United States of America  USD\tUnited States dollar
# 1083        1084  United States of America  USD\tUnited States dollar
#
#                   US_State                                            EdLevel  \
# 36    District of Columbia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37           Massachusetts  Some college/university study without earning ...
# 75               Minnesota       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 87                Maryland         Other doctoral degree (Ph.D., Ed.D., etc.)
# 118                   Iowa       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                    ...                                                ...
# 1068              Colorado    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1070              New York  Some college/university study without earning ...
# 1077             Tennessee  Secondary school (e.g. American high school, G...
# 1080                Oregon       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1083               Georgia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#      Gender              Age YearsCode  CompTotal        OpSys  \
# 36      Man  18-24 years old         8   103000.0  Linux-based
# 37      Man  35-44 years old        20   300000.0        MacOS
# 75      Man  45-54 years old        25   105000.0      Windows
# 87      Man  25-34 years old        18   100000.0      Windows
# 118     Man  25-34 years old        12   140000.0        MacOS
# ...     ...              ...       ...        ...          ...
# 1068    Man  25-34 years old        20   200000.0        MacOS
# 1070    Man  25-34 years old         8   144000.0        MacOS
# 1077    Man  55-64 years old        43    83000.0      Windows
# 1080    Man  25-34 years old        13     6303.0      Windows
# 1083    Man  35-44 years old         1   100000.0        MacOS
#
#                                                 DevType
# 36          Developer, embedded applications or devices
# 37                                  Developer, back-end
# 75    Developer, front-end;Developer, full-stack;Dev...
# 87    Engineer, data;Data scientist or machine learn...
# 118                               Developer, full-stack
# ...                                                 ...
# 1068  Developer, full-stack;Developer, back-end;DevO...
# 1070         Developer, front-end;Developer, full-stack
# 1077  Developer, full-stack;Developer, back-end;Data...
# 1080         Developer, front-end;Developer, full-stack
# 1083  Developer, front-end;Developer, desktop or ent...
#
# [100 rows x 11 columns]

# %%
#select the States what there are more respondends
top_states=list(df_dev_full_time_us['US_State'].value_counts().head(20).index)
top_states

df_top_states = df_dev_full_time_us[df_dev_full_time_us['US_State'].isin(top_states)]

df_top_states
# Out:
#        ResponseId                      MainBranch          Employment  \
# 37             38  I am a developer by profession  Employed full-time
# 75             76  I am a developer by profession  Employed full-time
# 87             88  I am a developer by profession  Employed full-time
# 128           129  I am a developer by profession  Employed full-time
# 143           144  I am a developer by profession  Employed full-time
# ...           ...                             ...                 ...
# 83404       83405  I am a developer by profession  Employed full-time
# 83427       83428  I am a developer by profession  Employed full-time
# 83430       83431  I am a developer by profession  Employed full-time
# 83434       83435  I am a developer by profession  Employed full-time
# 83436       83437  I am a developer by profession  Employed full-time
#
#                         Country                   Currency       US_State  \
# 37     United States of America  USD\tUnited States dollar  Massachusetts
# 75     United States of America  USD\tUnited States dollar      Minnesota
# 87     United States of America  USD\tUnited States dollar       Maryland
# 128    United States of America  USD\tUnited States dollar       Illinois
# 143    United States of America  USD\tUnited States dollar       Maryland
# ...                         ...                        ...            ...
# 83404  United States of America  USD\tUnited States dollar     California
# 83427  United States of America  USD\tUnited States dollar   Pennsylvania
# 83430  United States of America  USD\tUnited States dollar       Illinois
# 83434  United States of America  USD\tUnited States dollar          Texas
# 83436  United States of America  USD\tUnited States dollar     New Jersey
#
#                                                  EdLevel Gender  \
# 37     Some college/university study without earning ...    Man
# 75          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# 87            Other doctoral degree (Ph.D., Ed.D., etc.)    Man
# 128         Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# 143         Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# ...                                                  ...    ...
# 83404       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# 83427       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    Man
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Man
# 83436  Secondary school (e.g. American high school, G...    Man
#
#                    Age YearsCode  CompTotal        OpSys  \
# 37     35-44 years old        20   300000.0        MacOS
# 75     45-54 years old        25   105000.0      Windows
# 87     25-34 years old        18   100000.0      Windows
# 128    18-24 years old         7    54000.0      Windows
# 143    45-54 years old        38   200000.0      Windows
# ...                ...       ...        ...          ...
# 83404  25-34 years old         4    85000.0      Windows
# 83427  25-34 years old        13    86000.0      Windows
# 83430  45-54 years old        23   125000.0  Linux-based
# 83434  25-34 years old         6   160500.0        MacOS
# 83436  25-34 years old        10     1800.0      Windows
#
#                                                  DevType
# 37                                   Developer, back-end
# 75     Developer, front-end;Developer, full-stack;Dev...
# 87     Engineer, data;Data scientist or machine learn...
# 128                                Developer, full-stack
# 143                                  Developer, back-end
# ...                                                  ...
# 83404                              Developer, QA or test
# 83427  Developer, front-end;Developer, desktop or ent...
# 83430  Developer, front-end;Developer, full-stack;Dev...
# 83434                                Developer, back-end
# 83436  Data scientist or machine learning specialist;...
#
# [7736 rows x 13 columns]

# %% [markdown]
# ### 1. In which US states do you earn the most as a full-time developer?

# %% [markdown]
# ### 1.1 Calculating earning by state

# %%
# Counting the incoming by State. We s
df_top_states.groupby(['US_State']).mean()['CompTotal'].sort_values()
# Out:
# US_State
# Wisconsin         113141.715847
# Ohio              113766.168350
# Michigan          114752.978814
# Minnesota         124535.952381
# Utah              124826.986711
# Pennsylvania      126951.243077
# Florida           128528.026667
# North Carolina    128987.289474
# Georgia           129405.828452
# Oregon            130715.836207
# Texas             133133.644860
# Virginia          134344.569930
# Illinois          137051.713178
# Maryland          137314.567686
# Colorado          139868.341709
# Massachusetts     146134.920918
# New Jersey        151890.664948
# New York          158244.063465
# Washington        188517.843450
# California        196883.997717
# Name: CompTotal, dtype: float64

# %% [markdown]
# ### 1.1.1 Showing  results in a pie plot

# %%
# What State has the bigger incoming?

df_top_states.groupby(['US_State']).mean()['CompTotal'].sort_values().plot(kind='pie',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(8,10
))


plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY States\n')
plt.show()

# %% [markdown]
# ### 1.1.2 Showing  results in a bar plot

# %%
# Which State has the bigger incoming?

df_top_states.groupby(['US_State']).mean()['CompTotal'].head(20).sort_values().plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(13,5))


plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY States\n')
plt.show()

# %% [markdown]
# ### 2. What is the earning  by Education Level?

# %% [markdown]
# ##### 2.1 Calculating earning by Education Level

# %%
#Agrouping CompTotal by EdLevel
df_dev_full_time_us.groupby(['EdLevel']).mean()['CompTotal'].sort_values().dropna()
# Out:
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                   117499.015464
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    119351.729885
# Something else                                                                        122986.161290
# Primary/elementary school                                                             136646.000000
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          138521.165736
# Some college/university study without earning a degree                                138899.597222
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       151157.543043
# Professional degree (JD, MD, etc.)                                                    155564.128205
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            244711.617834
# Name: CompTotal, dtype: float64

# %% [markdown]
# ### 2.1.1 Showing  results in a pie plot

# %%
# showing using a plot pie
df_dev_full_time_drops_miss_rows.groupby(['EdLevel']).mean()['CompTotal'].sort_values().dropna().plot(kind='pie',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(12,8))

plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY Education Level\n')
plt.show()

# %% [markdown]
# ### 2.1.2 Showing results in a bar plot

# %%
#Agrouping CompTotal by EdLevel
df_dev_full_time_drops_miss_rows.groupby(['EdLevel']).mean()['CompTotal'].sort_values().dropna().plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(10,7))

plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY Education Level\n')
plt.show()

# %% [markdown]
# ### 3 What is the OpSys most used in the top countries?

# %% [markdown]
# ##### 3.1 Calculating earning by OS used

# %%
#Agrouping CompTotal by OpSys
df_dev_full_time_drops_miss_rows.groupby(['OpSys']).mean()['CompTotal'].dropna().sort_values()
# Out:
# OpSys
# Windows Subsystem for Linux (WSL)    123274.142180
# Windows                              129013.375870
# BSD                                  131181.818182
# Linux-based                          149319.966304
# MacOS                                153596.631104
# Other (please specify):              157229.292683
# Name: CompTotal, dtype: float64

# %% [markdown]
# ### 3.1.1 Showing the results in a plot pie

# %%
# Using a plot pie to show results

df_dev_full_time_drops_miss_rows.groupby(['OpSys']).mean()['CompTotal'].dropna().sort_values().plot(kind='pie',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(12,8))

plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY OPsys\n')
plt.show()

# %% [markdown]
# ### 3.1.2 Showing  results in a bar pot

# %%
# Which is the OS best paid?

df_dev_full_time_drops_miss_rows.groupby(['OpSys']).mean()['CompTotal'].dropna().sort_values().plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(12,8))

plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))
plt.ylabel('EARNINGs')
plt.title('\n INCOMINGS BY OPsys\n')
plt.show()

# %%
df_dev_full_time[df_dev_full_time.EdLevel=='Professional degree (JD, MD, etc.)']

df_selected_cols
df_dev_full_time.groupby(['Country']).mean()['ResponseId'].dropna().sort_values().head(20).plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='Country'>

# %%
df_dev_full_time=df_dev_full_time[df_dev_full_time.EdLevel=='Professional degree (JD, MD, etc.)']


df_dev_full_time['Country'].value_counts().head(10).plot(kind='pie',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(12,8))

np.sum(df_dev_full_time['Country'].value_counts())


country = df_dev_full_time.Country.value_counts().head(15)  # chosing top 10 


x = country.index               #coping column names
y = country/country.sum() *100  #calculating percentage 

f,ax1 = plt.subplots(figsize=(15,5)) #plotting graph
sns.barplot(x=x, y=y, ax=ax1);
ax1.set(xlabel = 'Countries', ylabel = 'Percentage %', title = "top countries having data Professional degrees");

# %%
# Aggregate the data so we can visualize it later

top_countries = list(df_dev_full_time['Country'].value_counts().head(10).index)

filtered_developer_data = df_dev_full_time[df_dev_full_time['Country'].isin(top_countries)]

aggregated_data = filtered_developer_data.groupby(['Country','EdLevel'], as_index=False)['ResponseId'].count()




total_respondents_per_country = df_dev_full_time['Country'].value_counts()

aggregated_data['Respondent Percentage'] = aggregated_data.apply(lambda x: x['ResponseId'] / total_respondents_per_country[x['Country']], axis=1).round(3)

 # Pivot the data
aggregated_data = aggregated_data[['Country', 'EdLevel', 'Respondent Percentage']]

pivoted_data = pd.pivot_table(aggregated_data, values='Respondent Percentage', index='Country', columns='EdLevel')


pivoted_data.plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(13,5))
plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))

plt.ylabel('Satisfaction Percentages')
plt.title('\nJOB SATISFACTION PERCENTAGE BY COUNTRY\n')
plt.show()

# %%
# Aggregate the data so we can visualize it later


top_countries = list(df_dev_full_time['Country'].value_counts().head(10).index)

filtered_developer_data = df_dev_full_time[df_dev_full_time['Country'].isin(top_countries)]

aggregated_data = filtered_developer_data.groupby(['Country','OpSys'], as_index=False)['ResponseId'].count()




total_respondents_per_country = df_dev_full_time['Country'].value_counts()

aggregated_data['Respondent Percentage'] = aggregated_data.apply(lambda x: x['ResponseId'] / total_respondents_per_country[x['Country']], axis=1).round(3)

 # Pivot the data
aggregated_data = aggregated_data[['Country', 'OpSys', 'Respondent Percentage']]

pivoted_data = pd.pivot_table(aggregated_data, values='Respondent Percentage', index='Country', columns='OpSys')


#pivoted_data.plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:20.5,-.4,dark=.4")),figsize=(13,5))
pivoted_data.plot(kind='bar',stacked=True,colormap=ListedColormap( sns.color_palette("ch:start=.2,rot=-.3")),figsize=(13,5))
#pivoted_data.plot(kind='bar',stacked=True,colormap=ListedColormap( sns.dark_palette("#69d")),figsize=(13,5))





plt.legend(loc="upper left", bbox_to_anchor=(1,1.02))

plt.ylabel('Satisfaction Percentages')
plt.title('\nJOB SATISFACTION PERCENTAGE BY COUNTRY\n')
plt.show()

# %%
df2=df[df.EdLevel=='Primary/elementary school']

df2
#df2.groupby(['Country']).mean()['ResponseId'].dropna().sort_values().head(10).plot(kind='pie',stacked=True,colormap=ListedColormap(sns.color_palette("ch:2.5,-.2,dark=.3")),figsize=(13,5))
df2['Country'].value_counts().head(10).plot(kind='bar',stacked=True,colormap=ListedColormap(sns.color_palette("ch:start=.2,rot=-.3")),figsize=(13,5))

np.sum(df2['Country'].value_counts())

country = df2.Country.value_counts().head(10)  # chosing top 10 


x = country.index               #coping column names
y = country/country.sum() *100  #calculating percentage 

f,ax1 = plt.subplots(figsize=(15,5)) #plotting graph
sns.barplot(x=x, y=y, ax=ax1);
ax1.set(xlabel = 'Countries', ylabel = 'Percentage %', title = "top countries having data scientists and machine learning specialist");
