# %% [markdown]
# ### A Look at the Data
#
# In order to get a better understanding of the data we will be looking at throughout this lesson, let's take a look at some of the characteristics of the dataset.
#
# First, let's read in the data and necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import ALookAtTheData as t
from IPython import display
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')

df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %%
As you work through the notebook(s) in this and future parts of this program, you will see some consistency in how to test your solutions to assure they match what we achieved!  In every workspace, there is a solution file and a test file.  There will be checks for each solution built into each notebook, but if you get stuck, you may also open the solution notebook to see how we find any of the solutions.  Let's take a look at an example.

### Question 1

**1.** Provide the number of rows and columns in this dataset.
# Out:
#   Cell In[16], line 1
#     As you work through the notebook(s) in this and future parts of this program, you will see some consistency in how to test your solutions to assure they match what we achieved!  In every workspace, there is a solution file and a test file.  There will be checks for each solution built into each notebook, but if you get stuck, you may also open the solution notebook to see how we find any of the solutions.  Let's take a look at an example.
#                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# We solved this one for you by providing the number of rows and columns:
# You can see how we are prompted that we solved for the number of rows and cols correctly!

num_rows = df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1] #Provide the number of columns in the dataset

t.check_rows_cols(num_rows, num_cols)
# Out:
# Nice job there are 19102 rows in the dataset!
# Nice job there are 154 columns in the dataset!

# %%
# If we made a mistake - a different prompt will appear

flipped_num_rows = df.shape[1] #Provide the number of rows in the dataset
flipped_num_cols = df.shape[0] #Provide the number of columns in the dataset

print(len(df))
print(df.shape[0])
print(len(df.columns))
print(df.shape[1])
print(df.info())
print(df.notnull())

t.check_rows_cols?

t.check_rows_cols(flipped_num_rows, flipped_num_cols)
# Out:
# 19102
# 19102
# 154
# 154
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19102 entries, 0 to 19101
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 22.4+ MB
# None
#        Respondent  Professional  ProgramHobby  Country  University  \
# 0            True          True          True     True        True
# 1            True          True          True     True        True
# 2            True          True          True     True        True
# 3            True          True          True     True        True
# 4            True          True          True     True        True
# 5            True          True          True     True        True
# 6            True          True          True     True        True
# 7            True          True          True     True        True
# 8            True          True          True     True        True
# 9            True          True          True     True        True
# 10           True          True          True     True        True
# 11           True          True          True     True        True
# 12           True          True          True     True        True
# 13           True          True          True     True        True
# 14           True          True          True     True        True
# 15           True          True          True     True        True
# 16           True          True          True     True        True
# 17           True          True          True     True        True
# 18           True          True          True     True        True
# 19           True          True          True     True        True
# 20           True          True          True     True        True
# 21           True          True          True     True        True
# 22           True          True          True     True        True
# 23           True          True          True     True        True
# 24           True          True          True     True        True
# 25           True          True          True     True        True
# 26           True          True          True     True        True
# 27           True          True          True     True        True
# 28           True          True          True     True        True
# 29           True          True          True     True        True
# ...           ...           ...           ...      ...         ...
# 19072        True          True          True     True        True
# 19073        True          True          True     True        True
# 19074        True          True          True     True        True
# 19075        True          True          True     True        True
# 19076        True          True          True     True        True
# 19077        True          True          True     True        True
# 19078        True          True          True     True        True
# 19079        True          True          True     True        True
# 19080        True          True          True     True        True
# 19081        True          True          True     True        True
# 19082        True          True          True     True        True
# 19083        True          True          True     True        True
# 19084        True          True          True     True        True
# 19085        True          True          True     True        True
# 19086        True          True          True     True        True
# 19087        True          True          True     True        True
# 19088        True          True          True     True        True
# 19089        True          True          True     True        True
# 19090        True          True          True     True        True
# 19091        True          True          True     True        True
# 19092        True          True          True     True        True
# 19093        True          True          True     True        True
# 19094        True          True          True     True        True
# 19095        True          True          True     True        True
# 19096        True          True          True     True        True
# 19097        True          True          True     True        True
# 19098        True          True          True     True        True
# 19099        True          True          True     True        True
# 19100        True          True          True     True        True
# 19101        True          True          True     True        True
#
#        EmploymentStatus  FormalEducation  MajorUndergrad  HomeRemote  \
# 0                  True             True           False       False
# 1                  True             True            True        True
# 2                  True             True            True        True
# 3                  True             True            True        True
# 4                  True             True            True        True
# 5                  True             True           False       False
# 6                  True             True            True        True
# 7                  True             True            True        True
# 8                  True             True            True        True
# 9                  True             True            True        True
# 10                 True             True            True        True
# 11                 True             True            True        True
# 12                 True             True            True       False
# 13                 True             True            True        True
# 14                 True             True            True        True
# 15                 True             True           False        True
# 16                 True             True           False       False
# 17                 True             True            True        True
# 18                 True             True            True        True
# 19                 True             True            True        True
# 20                 True             True            True        True
# 21                 True             True            True        True
# 22                 True             True            True        True
# 23                 True             True           False        True
# 24                 True             True            True        True
# 25                 True             True            True        True
# 26                 True             True            True        True
# 27                 True             True            True        True
# 28                 True             True            True        True
# 29                 True             True            True        True
# ...                 ...              ...             ...         ...
# 19072              True             True            True        True
# 19073              True             True            True        True
# 19074              True             True           False        True
# 19075              True             True            True        True
# 19076              True             True            True        True
# 19077              True             True            True        True
# 19078              True             True           False        True
# 19079              True             True            True        True
# 19080              True             True            True        True
# 19081              True             True            True        True
# 19082              True             True            True        True
# 19083              True             True            True        True
# 19084              True             True            True        True
# 19085              True             True            True        True
# 19086              True             True            True        True
# 19087              True             True            True        True
# 19088              True             True            True        True
# 19089              True             True            True        True
# 19090              True             True           False        True
# 19091              True             True            True        True
# 19092              True             True            True        True
# 19093              True             True            True        True
# 19094              True             True           False        True
# 19095              True             True            True        True
# 19096              True             True            True        True
# 19097              True             True            True        True
# 19098              True             True           False       False
# 19099              True             True            True        True
# 19100              True             True            True        True
# 19101              True             True            True        True
#
#        CompanySize       ...        StackOverflowMakeMoney  Gender  \
# 0            False       ...                          True    True
# 1             True       ...                          True    True
# 2             True       ...                          True    True
# 3             True       ...                          True    True
# 4             True       ...                         False   False
# 5            False       ...                          True   False
# 6             True       ...                          True    True
# 7             True       ...                          True    True
# 8             True       ...                          True    True
# 9            False       ...                          True    True
# 10            True       ...                          True    True
# 11            True       ...                         False   False
# 12           False       ...                          True    True
# 13            True       ...                          True    True
# 14            True       ...                          True    True
# 15           False       ...                          True    True
# 16           False       ...                          True    True
# 17            True       ...                          True    True
# 18            True       ...                         False   False
# 19            True       ...                          True    True
# 20            True       ...                         False   False
# 21            True       ...                          True    True
# 22            True       ...                          True    True
# 23           False       ...                          True    True
# 24            True       ...                         False   False
# 25            True       ...                          True    True
# 26            True       ...                         False   False
# 27            True       ...                         False   False
# 28            True       ...                          True    True
# 29            True       ...                         False   False
# ...            ...       ...                           ...     ...
# 19072         True       ...                         False   False
# 19073         True       ...                         False   False
# 19074        False       ...                          True    True
# 19075         True       ...                          True    True
# 19076         True       ...                          True    True
# 19077         True       ...                         False   False
# 19078        False       ...                          True    True
# 19079         True       ...                         False    True
# 19080         True       ...                         False   False
# 19081         True       ...                          True    True
# 19082         True       ...                         False   False
# 19083         True       ...                         False    True
# 19084         True       ...                          True    True
# 19085         True       ...                          True    True
# 19086         True       ...                          True    True
# 19087         True       ...                         False   False
# 19088         True       ...                          True    True
# 19089         True       ...                          True    True
# 19090        False       ...                         False   False
# 19091         True       ...                          True    True
# 19092         True       ...                         False   False
# 19093        False       ...                         False   False
# 19094        False       ...                          True    True
# 19095         True       ...                          True    True
# 19096         True       ...                          True    True
# 19097         True       ...                          True    True
# 19098        False       ...                         False   False
# 19099        False       ...                         False   False
# 19100         True       ...                          True    True
# 19101         True       ...                         False   False
#
#        HighestEducationParents   Race  SurveyLong  QuestionsInteresting  \
# 0                         True   True        True                  True
# 1                         True   True        True                  True
# 2                         True   True        True                  True
# 3                         True   True        True                  True
# 4                        False  False       False                 False
# 5                         True   True        True                  True
# 6                         True   True        True                  True
# 7                         True   True        True                  True
# 8                         True   True        True                  True
# 9                         True   True        True                  True
# 10                        True   True        True                  True
# 11                       False  False       False                 False
# 12                        True   True        True                  True
# 13                        True   True        True                  True
# 14                        True   True        True                  True
# 15                        True   True        True                  True
# 16                        True   True        True                  True
# 17                        True   True        True                  True
# 18                       False  False       False                 False
# 19                        True   True        True                  True
# 20                       False  False       False                 False
# 21                        True   True        True                  True
# 22                        True   True        True                  True
# 23                        True   True        True                  True
# 24                       False  False       False                 False
# 25                        True   True        True                  True
# 26                       False  False       False                 False
# 27                       False  False       False                 False
# 28                        True   True        True                  True
# 29                       False  False       False                 False
# ...                        ...    ...         ...                   ...
# 19072                    False  False       False                 False
# 19073                    False  False       False                 False
# 19074                     True   True        True                  True
# 19075                     True   True        True                  True
# 19076                     True   True        True                  True
# 19077                    False  False       False                 False
# 19078                     True   True        True                  True
# 19079                     True   True        True                  True
# 19080                    False  False       False                 False
# 19081                     True   True        True                  True
# 19082                    False  False       False                 False
# 19083                     True   True        True                  True
# 19084                     True   True        True                  True
# 19085                     True   True        True                  True
# 19086                     True   True        True                  True
# 19087                    False  False       False                 False
# 19088                     True   True        True                  True
# 19089                     True   True        True                  True
# 19090                    False  False       False                 False
# 19091                     True   True        True                  True
# 19092                    False  False       False                 False
# 19093                    False  False       False                 False
# 19094                     True   True        True                  True
# 19095                     True   True        True                  True
# 19096                     True   True        True                  True
# 19097                     True   True        True                  True
# 19098                    False  False       False                 False
# 19099                    False  False       False                 False
# 19100                     True   True        True                  True
# 19101                    False  False       False                 False
#
#        QuestionsConfusing  InterestedAnswers  Salary  ExpectedSalary
# 0                    True               True   False           False
# 1                    True               True   False            True
# 2                    True               True    True           False
# 3                    True               True   False           False
# 4                   False              False   False           False
# 5                    True               True   False           False
# 6                    True               True   False           False
# 7                    True               True   False           False
# 8                    True               True   False           False
# 9                    True               True   False           False
# 10                   True               True   False           False
# 11                  False              False   False           False
# 12                   True               True   False           False
# 13                   True               True   False           False
# 14                   True               True    True           False
# 15                   True               True   False           False
# 16                   True               True   False           False
# 17                   True               True    True           False
# 18                  False              False    True           False
# 19                   True               True   False           False
# 20                  False              False   False           False
# 21                   True               True   False           False
# 22                   True               True    True           False
# 23                   True               True   False           False
# 24                  False              False   False           False
# 25                   True               True    True           False
# 26                  False              False   False           False
# 27                  False              False   False           False
# 28                   True               True   False           False
# 29                  False              False   False           False
# ...                   ...                ...     ...             ...
# 19072               False              False   False           False
# 19073               False              False    True           False
# 19074                True               True   False           False
# 19075                True               True   False           False
# 19076                True               True   False           False
# 19077               False              False   False           False
# 19078                True               True   False           False
# 19079                True               True    True           False
# 19080               False              False   False           False
# 19081                True               True   False           False
# 19082               False              False   False           False
# 19083                True               True   False           False
# 19084                True               True   False           False
# 19085                True               True   False           False
# 19086                True               True    True           False
# 19087               False              False   False           False
# 19088                True               True    True           False
# 19089                True               True    True           False
# 19090               False              False   False           False
# 19091                True               True   False           False
# 19092               False              False   False           False
# 19093               False              False   False           False
# 19094                True               True   False           False
# 19095                True               True   False           False
# 19096                True               True   False           False
# 19097                True               True   False           False
# 19098               False              False   False           False
# 19099               False              False   False           False
# 19100                True               True    True           False
# 19101               False              False   False           False
#
# [19102 rows x 154 columns]
# That doesn't look like what we were expecting for the number of rows.
# That doesn't look like what we were expecting for the number of columns.

# %%
# If you want to know more about what the test function is expecting, 
# you can read the documentation the same way as any other funtion

t.check_rows_cols?

# %% [markdown]
# Now that you are familiar with how to test your code - let's have you answer your first question:
#
# ### Question 2
#
# **2.** Which columns had no missing values? Provide a set of column names that have no missing values.

# %%
no_nulls =df.notnull()#Provide a set of columns with 0 missing values.
#no_nulls =no_nulls.dropna()#Provide a set of columns with 0 missing values.
t.no_null_cols?
print('No nuls',no_nulls)


#quitar=df.notnull()
#df=df.where(quitar).dropna()
#print(df)
#df.head()

display.HTML(t.no_null_cols(no_nulls))
# Out:
# No nuls        Respondent  Professional  ProgramHobby  Country  University  \
# 0            True          True          True     True        True
# 1            True          True          True     True        True
# 2            True          True          True     True        True
# 3            True          True          True     True        True
# 4            True          True          True     True        True
# 5            True          True          True     True        True
# 6            True          True          True     True        True
# 7            True          True          True     True        True
# 8            True          True          True     True        True
# 9            True          True          True     True        True
# 10           True          True          True     True        True
# 11           True          True          True     True        True
# 12           True          True          True     True        True
# 13           True          True          True     True        True
# 14           True          True          True     True        True
# 15           True          True          True     True        True
# 16           True          True          True     True        True
# 17           True          True          True     True        True
# 18           True          True          True     True        True
# 19           True          True          True     True        True
# 20           True          True          True     True        True
# 21           True          True          True     True        True
# 22           True          True          True     True        True
# 23           True          True          True     True        True
# 24           True          True          True     True        True
# 25           True          True          True     True        True
# 26           True          True          True     True        True
# 27           True          True          True     True        True
# 28           True          True          True     True        True
# 29           True          True          True     True        True
# ...           ...           ...           ...      ...         ...
# 19072        True          True          True     True        True
# 19073        True          True          True     True        True
# 19074        True          True          True     True        True
# 19075        True          True          True     True        True
# 19076        True          True          True     True        True
# 19077        True          True          True     True        True
# 19078        True          True          True     True        True
# 19079        True          True          True     True        True
# 19080        True          True          True     True        True
# 19081        True          True          True     True        True
# 19082        True          True          True     True        True
# 19083        True          True          True     True        True
# 19084        True          True          True     True        True
# 19085        True          True          True     True        True
# 19086        True          True          True     True        True
# 19087        True          True          True     True        True
# 19088        True          True          True     True        True
# 19089        True          True          True     True        True
# 19090        True          True          True     True        True
# 19091        True          True          True     True        True
# 19092        True          True          True     True        True
# 19093        True          True          True     True        True
# 19094        True          True          True     True        True
# 19095        True          True          True     True        True
# 19096        True          True          True     True        True
# 19097        True          True          True     True        True
# 19098        True          True          True     True        True
# 19099        True          True          True     True        True
# 19100        True          True          True     True        True
# 19101        True          True          True     True        True
#
#        EmploymentStatus  FormalEducation  MajorUndergrad  HomeRemote  \
# 0                  True             True           False       False
# 1                  True             True            True        True
# 2                  True             True            True        True
# 3                  True             True            True        True
# 4                  True             True            True        True
# 5                  True             True           False       False
# 6                  True             True            True        True
# 7                  True             True            True        True
# 8                  True             True            True        True
# 9                  True             True            True        True
# 10                 True             True            True        True
# 11                 True             True            True        True
# 12                 True             True            True       False
# 13                 True             True            True        True
# 14                 True             True            True        True
# 15                 True             True           False        True
# 16                 True             True           False       False
# 17                 True             True            True        True
# 18                 True             True            True        True
# 19                 True             True            True        True
# 20                 True             True            True        True
# 21                 True             True            True        True
# 22                 True             True            True        True
# 23                 True             True           False        True
# 24                 True             True            True        True
# 25                 True             True            True        True
# 26                 True             True            True        True
# 27                 True             True            True        True
# 28                 True             True            True        True
# 29                 True             True            True        True
# ...                 ...              ...             ...         ...
# 19072              True             True            True        True
# 19073              True             True            True        True
# 19074              True             True           False        True
# 19075              True             True            True        True
# 19076              True             True            True        True
# 19077              True             True            True        True
# 19078              True             True           False        True
# 19079              True             True            True        True
# 19080              True             True            True        True
# 19081              True             True            True        True
# 19082              True             True            True        True
# 19083              True             True            True        True
# 19084              True             True            True        True
# 19085              True             True            True        True
# 19086              True             True            True        True
# 19087              True             True            True        True
# 19088              True             True            True        True
# 19089              True             True            True        True
# 19090              True             True           False        True
# 19091              True             True            True        True
# 19092              True             True            True        True
# 19093              True             True            True        True
# 19094              True             True           False        True
# 19095              True             True            True        True
# 19096              True             True            True        True
# 19097              True             True            True        True
# 19098              True             True           False       False
# 19099              True             True            True        True
# 19100              True             True            True        True
# 19101              True             True            True        True
#
#        CompanySize       ...        StackOverflowMakeMoney  Gender  \
# 0            False       ...                          True    True
# 1             True       ...                          True    True
# 2             True       ...                          True    True
# 3             True       ...                          True    True
# 4             True       ...                         False   False
# 5            False       ...                          True   False
# 6             True       ...                          True    True
# 7             True       ...                          True    True
# 8             True       ...                          True    True
# 9            False       ...                          True    True
# 10            True       ...                          True    True
# 11            True       ...                         False   False
# 12           False       ...                          True    True
# 13            True       ...                          True    True
# 14            True       ...                          True    True
# 15           False       ...                          True    True
# 16           False       ...                          True    True
# 17            True       ...                          True    True
# 18            True       ...                         False   False
# 19            True       ...                          True    True
# 20            True       ...                         False   False
# 21            True       ...                          True    True
# 22            True       ...                          True    True
# 23           False       ...                          True    True
# 24            True       ...                         False   False
# 25            True       ...                          True    True
# 26            True       ...                         False   False
# 27            True       ...                         False   False
# 28            True       ...                          True    True
# 29            True       ...                         False   False
# ...            ...       ...                           ...     ...
# 19072         True       ...                         False   False
# 19073         True       ...                         False   False
# 19074        False       ...                          True    True
# 19075         True       ...                          True    True
# 19076         True       ...                          True    True
# 19077         True       ...                         False   False
# 19078        False       ...                          True    True
# 19079         True       ...                         False    True
# 19080         True       ...                         False   False
# 19081         True       ...                          True    True
# 19082         True       ...                         False   False
# 19083         True       ...                         False    True
# 19084         True       ...                          True    True
# 19085         True       ...                          True    True
# 19086         True       ...                          True    True
# 19087         True       ...                         False   False
# 19088         True       ...                          True    True
# 19089         True       ...                          True    True
# 19090        False       ...                         False   False
# 19091         True       ...                          True    True
# 19092         True       ...                         False   False
# 19093        False       ...                         False   False
# 19094        False       ...                          True    True
# 19095         True       ...                          True    True
# 19096         True       ...                          True    True
# 19097         True       ...                          True    True
# 19098        False       ...                         False   False
# 19099        False       ...                         False   False
# 19100         True       ...                          True    True
# 19101         True       ...                         False   False
#
#        HighestEducationParents   Race  SurveyLong  QuestionsInteresting  \
# 0                         True   True        True                  True
# 1                         True   True        True                  True
# 2                         True   True        True                  True
# 3                         True   True        True                  True
# 4                        False  False       False                 False
# 5                         True   True        True                  True
# 6                         True   True        True                  True
# 7                         True   True        True                  True
# 8                         True   True        True                  True
# 9                         True   True        True                  True
# 10                        True   True        True                  True
# 11                       False  False       False                 False
# 12                        True   True        True                  True
# 13                        True   True        True                  True
# 14                        True   True        True                  True
# 15                        True   True        True                  True
# 16                        True   True        True                  True
# 17                        True   True        True                  True
# 18                       False  False       False                 False
# 19                        True   True        True                  True
# 20                       False  False       False                 False
# 21                        True   True        True                  True
# 22                        True   True        True                  True
# 23                        True   True        True                  True
# 24                       False  False       False                 False
# 25                        True   True        True                  True
# 26                       False  False       False                 False
# 27                       False  False       False                 False
# 28                        True   True        True                  True
# 29                       False  False       False                 False
# ...                        ...    ...         ...                   ...
# 19072                    False  False       False                 False
# 19073                    False  False       False                 False
# 19074                     True   True        True                  True
# 19075                     True   True        True                  True
# 19076                     True   True        True                  True
# 19077                    False  False       False                 False
# 19078                     True   True        True                  True
# 19079                     True   True        True                  True
# 19080                    False  False       False                 False
# 19081                     True   True        True                  True
# 19082                    False  False       False                 False
# 19083                     True   True        True                  True
# 19084                     True   True        True                  True
# 19085                     True   True        True                  True
# 19086                     True   True        True                  True
# 19087                    False  False       False                 False
# 19088                     True   True        True                  True
# 19089                     True   True        True                  True
# 19090                    False  False       False                 False
# 19091                     True   True        True                  True
# 19092                    False  False       False                 False
# 19093                    False  False       False                 False
# 19094                     True   True        True                  True
# 19095                     True   True        True                  True
# 19096                     True   True        True                  True
# 19097                     True   True        True                  True
# 19098                    False  False       False                 False
# 19099                    False  False       False                 False
# 19100                     True   True        True                  True
# 19101                    False  False       False                 False
#
#        QuestionsConfusing  InterestedAnswers  Salary  ExpectedSalary
# 0                    True               True   False           False
# 1                    True               True   False            True
# 2                    True               True    True           False
# 3                    True               True   False           False
# 4                   False              False   False           False
# 5                    True               True   False           False
# 6                    True               True   False           False
# 7                    True               True   False           False
# 8                    True               True   False           False
# 9                    True               True   False           False
# 10                   True               True   False           False
# 11                  False              False   False           False
# 12                   True               True   False           False
# 13                   True               True   False           False
# 14                   True               True    True           False
# 15                   True               True   False           False
# 16                   True               True   False           False
# 17                   True               True    True           False
# 18                  False              False    True           False
# 19                   True               True   False           False
# 20                  False              False   False           False
# 21                   True               True   False           False
# 22                   True               True    True           False
# 23                   True               True   False           False
# 24                  False              False   False           False
# 25                   True               True    True           False
# 26                  False              False   False           False
# 27                  False              False   False           False
# 28                   True               True   False           False
# 29                  False              False   False           False
# ...                   ...                ...     ...             ...
# 19072               False              False   False           False
# 19073               False              False    True           False
# 19074                True               True   False           False
# 19075                True               True   False           False
# 19076                True               True   False           False
# 19077               False              False   False           False
# 19078                True               True   False           False
# 19079                True               True    True           False
# 19080               False              False   False           False
# 19081                True               True   False           False
# 19082               False              False   False           False
# 19083                True               True   False           False
# 19084                True               True   False           False
# 19085                True               True   False           False
# 19086                True               True    True           False
# 19087               False              False   False           False
# 19088                True               True    True           False
# 19089                True               True    True           False
# 19090               False              False   False           False
# 19091                True               True   False           False
# 19092               False              False   False           False
# 19093               False              False   False           False
# 19094                True               True   False           False
# 19095                True               True   False           False
# 19096                True               True   False           False
# 19097                True               True   False           False
# 19098               False              False   False           False
# 19099               False              False   False           False
# 19100                True               True    True           False
# 19101               False              False   False           False
#
# [19102 rows x 154 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-cfff865ee056> in <module>()
#      10 #df.head()
#      11
# ---> 12 display.HTML(t.no_null_cols(no_nulls))
#
# /home/workspace/ALookAtTheData.py in no_null_cols(no_nulls)
#      37     This function will print a statement related to whether or not you provided the correct set of columns with no missing values
#      38     '''
# ---> 39     if no_nulls == s.no_nulls:
#      40         print("Nice job that looks right!")
#      41         return display_gif('https://bit.ly/2K9X0gD')
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### Question 3
#
# **3.** Which columns have the most missing values?  Provide a set of column names that have more than 75% if their values missing.

# %%
most_missing_cols = #Provide a set of columns with more than 75% of the values missing
#df.notnull().sum()

t.most_missing_cols(most_missing_cols)
# Out:
#   File "<ipython-input-44-80515319466c>", line 1
#     most_missing_cols = #Provide a set of columns with more than 75% of the values missing
#                                                                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Question 4
#
# **4.** Provide a pandas series of the different **Professional** status values in the dataset along with the count of the number of individuals with each status.  Store this pandas series in **status_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each status.

# %%
status_vals = #Provide a pandas series of the counts for each Professional status

# The below should be a bar chart of the proportion of individuals in each professional category if your status_vals
# is set up correctly.

(status_vals/df.shape[0]).plot(kind="bar");
plt.title("What kind of developer are you?");

# %% [markdown]
# ### Question 5
#
# **5.** Provide a pandas series of the different **FormalEducation** status values in the dataset along with the count of how many individuals received that formal education.  Store this pandas series in **ed_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each status.

# %%
ed_vals = #Provide a pandas series of the counts for each FormalEducation status

# The below should be a bar chart of the proportion of individuals in your ed_vals
# if it is set up correctly.

(ed_vals/df.shape[0]).plot(kind="bar");
plt.title("Formal Education");

# %% [markdown]
# ### Question 6
#
# **6.** Provide a pandas series of the different **Country** values in the dataset along with the count of how many individuals are from each country.  Store this pandas series in **count_vals**.  If you are correct, you should see a bar chart of the proportion of individuals in each country.

# %%
count_vals = #Provide a pandas series of the counts for each Country

# The below should be a bar chart of the proportion of the top 10 countries for the
# individuals in your count_vals if it is set up correctly.

(count_vals[:10]/df.shape[0]).plot(kind="bar");
plt.title("Country");

# %% [markdown]
# Feel free to explore the dataset further to gain additional familiarity with the columns and rows in the dataset.  You will be working pretty closely with this dataset throughout this lesson.
