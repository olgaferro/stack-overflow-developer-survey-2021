# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error


import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema=pd.read_csv('./survey_results_schema.csv')


df.head()
#df.hist()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
#df.groupby(['Country'])['Gender']



df.groupby(['OrgSize']).mean()['CompTotal'].sort_values()
# Out:
# OrgSize
# 5,000 to 9,999 employees                              1.644995e+06
# 2 to 9 employees                                      2.029284e+06
# 500 to 999 employees                                  2.740625e+06
# 10 to 19 employees                                    1.458523e+07
# 20 to 99 employees                                    6.601722e+11
# Just me - I am a freelancer, sole proprietor, etc.    1.734906e+12
# 100 to 499 employees                                  1.173964e+25
# 10,000 or more employees                              1.122694e+36
# I don’t know                                          1.020408e+50
# 1,000 to 4,999 employees                              1.958097e+70
# Name: CompTotal, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df[df.Country=='United States of America']
   
df[df['MainBranch'].str.contains("I am")]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.groupby(['Age']).mean()['CompTotal'].sort_values().dropna()
# Out:
# Age
# 45-54 years old       1.727865e+06
# 35-44 years old       2.156959e+06
# 55-64 years old       5.101432e+06
# Prefer not to say     1.508004e+08
# Under 18 years old    5.076322e+08
# 65 years or older     4.458599e+37
# 18-24 years old       1.067094e+49
# 25-34 years old       4.270584e+69
# Name: CompTotal, dtype: float64

# %%
countries=list(df['Country'].value_counts().head(10).index)
countries

f = df[df['Country'].isin(countries)]
f
# Out:
#        ResponseId                              MainBranch  \
# 1               2  I am a student who is learning to code
# 4               5          I am a developer by profession
# 5               6  I am a student who is learning to code
# 6               7             I code primarily as a hobby
# 8               9          I am a developer by profession
# ...           ...                                     ...
# 83433       83434          I am a developer by profession
# 83434       83435          I am a developer by profession
# 83436       83437          I am a developer by profession
# 83437       83438          I am a developer by profession
# 83438       83439          I am a developer by profession
#
#                                               Employment  \
# 1                                     Student, full-time
# 4      Independent contractor, freelancer, or self-em...
# 5                                     Student, part-time
# ...

# %%
df
#df.groupby(['EdLevel']).mean()['CompTotal'].sort_values().dropna()
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['EdLevel'].value_counts()


#df[df['DevType']== 'Data scientist or machine learning specialist'] #made a new dataframe as ds

#df.EdLevel.value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       17512
# Some college/university study without earning a degree                                10589
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2567
# Primary/elementary school                                                              2479
# Associate degree (A.A., A.S., etc.)                                                    2231
# Something else                                                                         1601
# Professional degree (JD, MD, etc.)                                                     1256
# Name: EdLevel, dtype: int64

# %%
df.groupby(['DevType']).mean()['CompTotal'].sort_values().dropna()
# Out:
# DevType
# Developer, desktop or enterprise applications;Developer, back-end;Academic researcher;Database administrator;Developer, QA or test;Developer, game or graphics;Developer, embedded applications or devices;DevOps specialist;Designer;System administrator                                                                                                                                                                                                                                                                                          0.000000e+00
# ...

# %%
df.groupby(['OpSys']).mean()['CompTotal'].sort_values().dropna()
# Out:
# OpSys
# BSD                                  3.044876e+06
# Other (please specify):              2.837970e+07
# MacOS                                4.570803e+11
# Linux-based                          8.578658e+24
# Windows                              4.161465e+48
# Windows Subsystem for Linux (WSL)    7.032349e+70
# Name: CompTotal, dtype: float64

# %%
df.groupby(['Gender']).mean()['CompTotal']
# Out:
# Gender
# Man                                                                                   2.294315e+69
# Man;Non-binary, genderqueer, or gender non-conforming                                 9.708984e+05
# Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:          1.626000e+04
# Man;Or, in your own words:                                                            3.262329e+05
# Man;Woman                                                                             1.188500e+06
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                           2.633880e+06
# Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:    6.370983e+04
# Man;Woman;Or, in your own words:                                                      7.500000e+06
# Non-binary, genderqueer, or gender non-conforming                                     6.633183e+05
# ...

# %%
df.groupby(df['OpSys']).mean()['CompTotal'].sort_values()
# Out:
# OpSys
# BSD                                  3.044876e+06
# Other (please specify):              2.837970e+07
# MacOS                                4.570803e+11
# Linux-based                          8.578658e+24
# Windows                              4.161465e+48
# Windows Subsystem for Linux (WSL)    7.032349e+70
# Name: CompTotal, dtype: float64

# %%
df.Country.value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
lista_countries=list(df.groupby(['Country']).size())
          


len(lista_countries)
# Out:
# 181

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       17512
# Some college/university study without earning a degree                                10589
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2567
# Primary/elementary school                                                              2479
# Associate degree (A.A., A.S., etc.)                                                    2231
# Something else                                                                         1601
# Professional degree (JD, MD, etc.)                                                     1256
# Name: EdLevel, dtype: int64
